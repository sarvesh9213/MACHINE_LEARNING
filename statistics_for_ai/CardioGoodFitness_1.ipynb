# %% [markdown]
# ![ProblemStatement.png](attachment:f7c530a9-4c77-447d-b276-365e412e9217.png)

# %% [markdown]
# - ## Key Variables Identified for Study:
# - ## Product purchased: TM195, TM498, or TM798.
# - ## Gender of the customer.
# - ## Age (in years).
# - ## Education (in years).
# - ## Relationship status: Single or partnered.
# - ## Annual household income.
# - ## Average number of times the customer plans to use the treadmill each week.
# - ## Average number of miles the customer expects to walk or run each week.
# - ## Self-rated fitness level on a scale of 1 (poor shape) to 5 (excellent shape).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"CardioGoodFitness.csv")

# %%
df.head(95)
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0    TM195   18    Male         14        Single      3        4   29562
# 1    TM195   19    Male         15        Single      2        3   31836
# 2    TM195   19  Female         14     Partnered      4        3   30699
# 3    TM195   19    Male         12        Single      3        3   32973
# 4    TM195   20    Male         13     Partnered      4        2   35247
# ..     ...  ...     ...        ...           ...    ...      ...     ...
# 90   TM498   23    Male         16     Partnered      4        3   45480
# 91   TM498   23  Female         16     Partnered      3        2   43206
# 92   TM498   23  Female         14        Single      3        2   40932
# 93   TM498   23    Male         16     Partnered      3        3   45480
# 94   TM498   24  Female         14        Single      3        2   40932
#
#     Miles
# 0     112
# 1      75
# 2      66
# 3      85
# 4      47
# ..    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.shape
# Out:
# (180, 9)

# %%
a = 100
a

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include = 'all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
df.describe(include = 'object')
# Out:
#        Product Gender MaritalStatus
# count      180    180           180
# unique       3      2             2
# top      TM195   Male     Partnered
# freq        80    104           107

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
df['Age'].mean()
# Out:
# 28.788888888888888

# %%
df['Age'].median()
# Out:
# 26.0

# %%
df['Age'].skew()

# %%
df['Age'].kurt()

# %%
df['Age'].std()

# %%
df['Age'].var()

# %%
plt.figure(figsize = (10,5))
plt.title('AGE Distribution')
sns.histplot(df['Age'],kde = True,bins = 10)
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.title('AGE Distribution')
sns.boxplot(x = df['Age'])
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.title('AGE Distribution')
sns.boxplot(df['Age'])
plt.show()

# %%
df2 = pd.read_csv("D:\\desktop\\ML\\DATA\\USA_Housing.csv")

# %%
df2.head()

# %%
df3 = pd.read_csv(r"D:\desktop\ML\Machine Learning\NEW ML\Class 3_20_11_2024\DATA PREPROCESSING\Sal_Pred.csv")

# %%
df3.head()

# %%
df3.shape

# %% [markdown]
# ![image.png](attachment:c38677a2-262a-47f6-b2de-f8482a5a9b75.png)

# %%
import numpy as np

# %%
 x = [ 10,11,12,25,25,27,31,33,34,34,35,36,43,50,59]

# %%
x
# Out:
# [10, 11, 12, 25, 25, 27, 31, 33, 34, 34, 35, 36, 43, 50, 59]

# %%
len(x)
# Out:
# 15

# %%
# Outlier
LL= Q1 - 1.5*IQR
UL = Q3 + 1.5*IQR

# %%
Q1 = np.percentile(x,25)
print(Q1)
# Out:
# 25.0

# %%
Q2 = np.percentile(x,50)
print(Q2)
# Out:
# 33.0

# %%
Q3 = np.percentile(x,75)
print(Q3)
# Out:
# 35.5

# %%
# IQR = Inter Quartile Range

# %%
 IQR = Q3-Q1
print(IQR)
# Out:
# 10.5

# %%
print(LL)
print("*****")
print(UL)
# Out:
# 9.25
# *****
# 51.25

# %% [markdown]
# ![image.png](attachment:88201aa8-f24a-431d-9547-85aea6ee5a92.png)

# %%
data = [26.0,15.0,20.5,31,-350.0,31,30.5]

# %%
q1 = np.percentile(data,25)

# %%
q1
# Out:
# 17.75

# %%
new_data = sorted(data)

# %%
new_data
# Out:
# [-350.0, 15.0, 20.5, 26.0, 30.5, 31, 31]

# %%
q_1 = np.percentile(new_data,25)

# %%
q_1
# Out:
# 17.75

# %%
q_2 = np.percentile(new_data,50)

# %%
q_2
# Out:
# 26.0

# %%
q_3 = np.percentile(new_data,75)

# %%
IQR = q_3 - q_1

# %%
IQR
# Out:
# 13.0

# %%
ll =  q_1-1.5*IQR

# %%
ll
# Out:
# -1.75

# %%
 x = [10,12,11,13,12,14,110]

# %%
 X_array = np.array(x)

# %%
X_mean = X_array.mean()

# %%
X_median = np.median(X_array)

# %%
X_median
# Out:
# 12.0

# %%
X_mean
# Out:
# 26.0

# %%
X_sd = X_array.std()

# %%
X_sd
# Out:
# 34.31367907159726

# %%
Z_score = (x[0]-X_mean)/X_sd

# %%
Z_score
# Out:
# -0.4662863450641704

# %%
from scipy.stats import skew

# %%
skewness_x = skew(x)

# %%
skewness_x
# Out:
# 2.03604255046447

# %% [markdown]
# ![image.png](attachment:c2b1f59d-83ac-4cd6-97a9-da860a1990b6.png)

# %% [markdown]
# ![image.png](attachment:0fe205f9-d7d3-4ae7-8963-82deafb466d7.png)
